# %%
from flask import Flask
app = Flask(__name__)

@app.route("/")
def hello():
    return "<h1>hello world!</h1>"

@app.route("/profile/<username>")
def get_profile(username):
    return "profile: " + username

@app.route("/message/<int:user_id>")
def get_user_id(user_id):
    return f"user_id :  {user_id}"

if __name__ == "__main__":
    app.run(host="0.0.0.0", port="8080")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8080
#  * Running on http://210.101.236.205:8080
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Jan/2026 22:02:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2026 22:02:51] "GET /message/123 HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2026 22:02:55] "GET /message/앙기모딱 HTTP/1.1" 404 -
# 127.0.0.1 - - [28/Jan/2026 22:03:00] "GET /profile/앙기모딱 HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2026 22:40:14] "GET /profile/아 HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2026 22:40:19] "GET /profile/프로파일 HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2026 22:50:09] "GET /json_test HTTP/1.1" 404 -

# %% [markdown]
# ### <b>flask로 REST API 구현하기

# %%
from flask import Flask, jsonify
app = Flask(__name__)

@app.route('/json_test')
def hello_json():
    data = {'name' : 'kim', 'family' : 'Byun'}
    return jsonify(data)

@app.route('/server_info')
def server_json():
    data = { 'server_name' : '0.0.0.0', 'server_port' : '8081' }
    return jsonify(data)

# %%
if __name__ == '__main__':
    app.run(host="0.0.0.0", port="8081")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8081
#  * Running on http://210.101.236.205:8081
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Jan/2026 22:57:40] "GET /json_test HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2026 22:57:41] "GET /json_test HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2026 22:57:41] "GET /json_test HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2026 22:57:42] "GET /json_test HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2026 22:57:42] "GET /json_test HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2026 22:58:19] "GET /server_info HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2026 23:01:01] "GET /json_test HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2026 23:01:52] "GET /server_info HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2026 23:02:17] "GET /json_test HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jan/2026 23:04:58] "GET /server_info HTTP/1.1" 200 -

# %%
# !http get http://localhost:8081/json_test
